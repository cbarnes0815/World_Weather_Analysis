# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import random
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

#import time library and datetime module
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
#Perform API Call

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_country= city_weather["sys"]["country"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
    
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | clyde river
# Processing Record 2 of Set 1 | berdigestyakh
# Processing Record 3 of Set 1 | tiksi
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 1 | ostrovnoy
# Processing Record 7 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | chato
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | sungurlu
# Processing Record 13 of Set 1 | kabo
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | mogadishu
# Processing Record 16 of Set 1 | provideniya
# Processing Record 17 of Set 1 | morondava
# Processing Record 18 of Set 1 | ribeira grande
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | auchi
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | husavik
# Processing Record 23 of Set 1 | esperance
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 1 | najran
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | carlsbad
# Processing Record 33 of Set 1 | tevaitoa
# Processing Record 34 of Set 1 | alofi
# Processing Record 35 of Set 1 | maltahohe
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | lazaro cardenas
# Processing Record 38 of Set 1 | coahuayana
# Processing Record 39 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 1 | zeya
# Processing Record 41 of Set 1 | saint-denis
# Processing Record 42 of Set 1 | saskylakh
# Processing Record 43 of Set 1 | richards bay
# Processing Record 44 of Set 1 | san antonio
# Processing Record 45 of Set 1 | sokoto
# Processing Record 46 of Set 1 | tasiilaq
# Processing Record 47 of Set 1 | oranjestad
# Processing Record 48 of Set 1 | minot
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | naftah
# City not found. Skipping...
# Processing Record 1 of Set 2 | luanda
# Processing Record 2 of Set 2 | jiujiang
# Processing Record 3 of Set 2 | billings
# Processing Record 4 of Set 2 | bethel
# Processing Record 5 of Set 2 | sooke
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | gamba
# Processing Record 8 of Set 2 | fairbanks
# Processing Record 9 of Set 2 | puerto ayora
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 2 | voh
# Processing Record 13 of Set 2 | chokurdakh
# Processing Record 14 of Set 2 | giyon
# Processing Record 15 of Set 2 | lagoa
# Processing Record 16 of Set 2 | port-gentil
# Processing Record 17 of Set 2 | kapaa
# Processing Record 18 of Set 2 | waingapu
# Processing Record 19 of Set 2 | tuktoyaktuk
# Processing Record 20 of Set 2 | sobolevo
# Processing Record 21 of Set 2 | east london
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | atuona
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | pochutla
# Processing Record 26 of Set 2 | luderitz
# Processing Record 27 of Set 2 | turukhansk
# Processing Record 28 of Set 2 | doha
# Processing Record 29 of Set 2 | itarema
# Processing Record 30 of Set 2 | vila velha
# Processing Record 31 of Set 2 | vao
# Processing Record 32 of Set 2 | vaitape
# Processing Record 33 of Set 2 | liverpool
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | gigmoto
# Processing Record 37 of Set 2 | jinchang
# Processing Record 38 of Set 2 | svetlyy
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | port elizabeth
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | asau
# Processing Record 43 of Set 2 | baherden
# Processing Record 44 of Set 2 | zhaoyuan
# Processing Record 45 of Set 2 | upernavik
# Processing Record 46 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 2 | nanortalik
# Processing Record 48 of Set 2 | hasaki
# Processing Record 49 of Set 2 | fortuna
# Processing Record 50 of Set 2 | tautira
# Processing Record 1 of Set 3 | butaritari
# Processing Record 2 of Set 3 | poplar bluff
# Processing Record 3 of Set 3 | atar
# Processing Record 4 of Set 3 | fort nelson
# Processing Record 5 of Set 3 | marsa
# Processing Record 6 of Set 3 | prince george
# Processing Record 7 of Set 3 | taixing
# Processing Record 8 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 3 | kondinskoye
# Processing Record 10 of Set 3 | vardo
# Processing Record 11 of Set 3 | sechura
# Processing Record 12 of Set 3 | marawi
# Processing Record 13 of Set 3 | shache
# Processing Record 14 of Set 3 | kaveripattinam
# Processing Record 15 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 3 | goiana
# Processing Record 17 of Set 3 | ugoofaaru
# Processing Record 18 of Set 3 | isangel
# Processing Record 19 of Set 3 | canavieiras
# Processing Record 20 of Set 3 | auki
# Processing Record 21 of Set 3 | castro
# Processing Record 22 of Set 3 | lakshettipet
# Processing Record 23 of Set 3 | tuatapere
# Processing Record 24 of Set 3 | sangar
# Processing Record 25 of Set 3 | tres arroyos
# Processing Record 26 of Set 3 | torbay
# Processing Record 27 of Set 3 | aksu
# Processing Record 28 of Set 3 | broome
# Processing Record 29 of Set 3 | mayo
# Processing Record 30 of Set 3 | cayenne
# Processing Record 31 of Set 3 | worthington
# Processing Record 32 of Set 3 | touros
# Processing Record 33 of Set 3 | uyemskiy
# Processing Record 34 of Set 3 | saldanha
# Processing Record 35 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | bambous virieux
# Processing Record 38 of Set 3 | kincardine
# Processing Record 39 of Set 3 | bluff
# Processing Record 40 of Set 3 | dembi dolo
# Processing Record 41 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 3 | norman wells
# Processing Record 43 of Set 3 | marystown
# Processing Record 44 of Set 3 | songkhla
# Processing Record 45 of Set 3 | llanes
# Processing Record 46 of Set 3 | bardiyah
# Processing Record 47 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 3 | busselton
# Processing Record 49 of Set 3 | praia da vitoria
# Processing Record 50 of Set 3 | payo
# Processing Record 1 of Set 4 | srednekolymsk
# Processing Record 2 of Set 4 | richmond
# Processing Record 3 of Set 4 | puerto escondido
# Processing Record 4 of Set 4 | karratha
# Processing Record 5 of Set 4 | steamboat springs
# Processing Record 6 of Set 4 | qena
# Processing Record 7 of Set 4 | talcahuano
# Processing Record 8 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 4 | datong
# Processing Record 10 of Set 4 | muscle shoals
# Processing Record 11 of Set 4 | bontang
# Processing Record 12 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 4 | hofn
# Processing Record 14 of Set 4 | portland
# Processing Record 15 of Set 4 | lompoc
# Processing Record 16 of Set 4 | kinna
# Processing Record 17 of Set 4 | seoul
# Processing Record 18 of Set 4 | hudiksvall
# Processing Record 19 of Set 4 | nadym
# Processing Record 20 of Set 4 | gao
# Processing Record 21 of Set 4 | tigre
# Processing Record 22 of Set 4 | virginia beach
# Processing Record 23 of Set 4 | nuuk
# Processing Record 24 of Set 4 | severo-kurilsk
# Processing Record 25 of Set 4 | yilan
# Processing Record 26 of Set 4 | cockburn town
# Processing Record 27 of Set 4 | gizo
# Processing Record 28 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 4 | georgetown
# Processing Record 30 of Set 4 | huarmey
# Processing Record 31 of Set 4 | quelimane
# Processing Record 32 of Set 4 | forbes
# Processing Record 33 of Set 4 | mendi
# Processing Record 34 of Set 4 | talnakh
# Processing Record 35 of Set 4 | obo
# Processing Record 36 of Set 4 | bonnyville
# Processing Record 37 of Set 4 | hovd
# Processing Record 38 of Set 4 | clifton
# Processing Record 39 of Set 4 | enshi
# Processing Record 40 of Set 4 | victoria
# Processing Record 41 of Set 4 | rajula
# Processing Record 42 of Set 4 | gurskoye
# City not found. Skipping...
# Processing Record 43 of Set 4 | mar del plata
# Processing Record 44 of Set 4 | pucallpa
# Processing Record 45 of Set 4 | santa marta
# Processing Record 46 of Set 4 | vylgort
# City not found. Skipping...
# Processing Record 47 of Set 4 | northam
# Processing Record 48 of Set 4 | staunton
# Processing Record 49 of Set 4 | aklavik
# Processing Record 50 of Set 4 | anaconda
# Processing Record 1 of Set 5 | kavieng
# Processing Record 2 of Set 5 | mehamn
# Processing Record 3 of Set 5 | ixtapa
# Processing Record 4 of Set 5 | sretensk
# Processing Record 5 of Set 5 | lubango
# Processing Record 6 of Set 5 | cidreira
# Processing Record 7 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 5 | camacha
# Processing Record 9 of Set 5 | nemuro
# Processing Record 10 of Set 5 | bayeux
# Processing Record 11 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 12 of Set 5 | yelovo
# Processing Record 13 of Set 5 | raudeberg
# Processing Record 14 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 15 of Set 5 | aloleng
# Processing Record 16 of Set 5 | newport
# Processing Record 17 of Set 5 | ilulissat
# Processing Record 18 of Set 5 | lewistown
# Processing Record 19 of Set 5 | san andres
# Processing Record 20 of Set 5 | san patricio
# Processing Record 21 of Set 5 | santa cruz cabralia
# Processing Record 22 of Set 5 | vestmannaeyjar
# Processing Record 23 of Set 5 | hami
# Processing Record 24 of Set 5 | santo antonio do ica
# Processing Record 25 of Set 5 | saint-philippe
# Processing Record 26 of Set 5 | hearst
# Processing Record 27 of Set 5 | ancud
# Processing Record 28 of Set 5 | tlaxiaco
# City not found. Skipping...
# Processing Record 29 of Set 5 | okha
# Processing Record 30 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 5 | gornopravdinsk
# Processing Record 32 of Set 5 | san vicente
# Processing Record 33 of Set 5 | linjiang
# Processing Record 34 of Set 5 | maba
# Processing Record 35 of Set 5 | naze
# Processing Record 36 of Set 5 | pevek
# Processing Record 37 of Set 5 | varkaus
# Processing Record 38 of Set 5 | kargopol
# Processing Record 39 of Set 5 | jamestown
# Processing Record 40 of Set 5 | tandur
# Processing Record 41 of Set 5 | ponta do sol
# Processing Record 42 of Set 5 | lebu
# Processing Record 43 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 5 | galdar
# Processing Record 45 of Set 5 | broken hill
# Processing Record 46 of Set 5 | blackwater
# Processing Record 47 of Set 5 | ngunguru
# Processing Record 48 of Set 5 | huntsville
# Processing Record 49 of Set 5 | dzhebariki-khaya
# Processing Record 50 of Set 5 | port lincoln
# Processing Record 1 of Set 6 | pisco
# Processing Record 2 of Set 6 | bowen
# Processing Record 3 of Set 6 | belomorsk
# Processing Record 4 of Set 6 | lukovetskiy
# Processing Record 5 of Set 6 | faanui
# Processing Record 6 of Set 6 | mangan
# Processing Record 7 of Set 6 | ajaccio
# Processing Record 8 of Set 6 | bilma
# Processing Record 9 of Set 6 | pitlochry
# Processing Record 10 of Set 6 | kaitangata
# Processing Record 11 of Set 6 | voiron
# Processing Record 12 of Set 6 | abu samrah
# Processing Record 13 of Set 6 | wanning
# Processing Record 14 of Set 6 | flin flon
# Processing Record 15 of Set 6 | santiago
# Processing Record 16 of Set 6 | yeppoon
# Processing Record 17 of Set 6 | tori fatehpur
# Processing Record 18 of Set 6 | vila do maio
# Processing Record 19 of Set 6 | japura
# Processing Record 20 of Set 6 | mount isa
# Processing Record 21 of Set 6 | jaora
# Processing Record 22 of Set 6 | taksimo
# Processing Record 23 of Set 6 | hit
# Processing Record 24 of Set 6 | kieta
# Processing Record 25 of Set 6 | kem
# Processing Record 26 of Set 6 | dauriya
# Processing Record 27 of Set 6 | kruisfontein
# Processing Record 28 of Set 6 | ahipara
# Processing Record 29 of Set 6 | souillac
# Processing Record 30 of Set 6 | sao filipe
# Processing Record 31 of Set 6 | poso
# Processing Record 32 of Set 6 | kodiak
# Processing Record 33 of Set 6 | kavaratti
# Processing Record 34 of Set 6 | ust-karsk
# Processing Record 35 of Set 6 | mandera
# Processing Record 36 of Set 6 | oshawa
# Processing Record 37 of Set 6 | yibin
# Processing Record 38 of Set 6 | birjand
# Processing Record 39 of Set 6 | kualakapuas
# Processing Record 40 of Set 6 | nikolskoye
# Processing Record 41 of Set 6 | uvat
# Processing Record 42 of Set 6 | kharp
# Processing Record 43 of Set 6 | bhainsdehi
# Processing Record 44 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 6 | aykhal
# Processing Record 46 of Set 6 | ewa beach
# Processing Record 47 of Set 6 | soyo
# Processing Record 48 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 6 | gladstone
# Processing Record 50 of Set 6 | tashtyp
# Processing Record 1 of Set 7 | stornoway
# Processing Record 2 of Set 7 | fare
# Processing Record 3 of Set 7 | emerald
# Processing Record 4 of Set 7 | ust-tsilma
# Processing Record 5 of Set 7 | sukheke
# City not found. Skipping...
# Processing Record 6 of Set 7 | kropotkin
# Processing Record 7 of Set 7 | cottonwood
# Processing Record 8 of Set 7 | lavrentiya
# Processing Record 9 of Set 7 | labuhan
# Processing Record 10 of Set 7 | tucurui
# Processing Record 11 of Set 7 | buraydah
# Processing Record 12 of Set 7 | houma
# Processing Record 13 of Set 7 | tura
# Processing Record 14 of Set 7 | ust-kuyga
# Processing Record 15 of Set 7 | chatham
# Processing Record 16 of Set 7 | murray bridge
# Processing Record 17 of Set 7 | merrill
# Processing Record 18 of Set 7 | constantine
# Processing Record 19 of Set 7 | malpe
# Processing Record 20 of Set 7 | ambon
# Processing Record 21 of Set 7 | saint george
# Processing Record 22 of Set 7 | port hardy
# Processing Record 23 of Set 7 | juneau
# Processing Record 24 of Set 7 | chuy
# Processing Record 25 of Set 7 | iqaluit
# Processing Record 26 of Set 7 | comodoro rivadavia
# Processing Record 27 of Set 7 | chicama
# Processing Record 28 of Set 7 | bubaque
# Processing Record 29 of Set 7 | longyan
# Processing Record 30 of Set 7 | palamos
# Processing Record 31 of Set 7 | grand gaube
# Processing Record 32 of Set 7 | sassandra
# Processing Record 33 of Set 7 | butia
# Processing Record 34 of Set 7 | almaznyy
# Processing Record 35 of Set 7 | port augusta
# Processing Record 36 of Set 7 | cap malheureux
# Processing Record 37 of Set 7 | nome
# Processing Record 38 of Set 7 | peleduy
# Processing Record 39 of Set 7 | port hedland
# Processing Record 40 of Set 7 | yulara
# Processing Record 41 of Set 7 | avera
# Processing Record 42 of Set 7 | one hundred mile house
# City not found. Skipping...
# Processing Record 43 of Set 7 | college
# Processing Record 44 of Set 7 | jardim
# Processing Record 45 of Set 7 | labytnangi
# Processing Record 46 of Set 7 | hambantota
# Processing Record 47 of Set 7 | greensburg
# Processing Record 48 of Set 7 | qaqortoq
# Processing Record 49 of Set 7 | nouadhibou
# Processing Record 50 of Set 7 | asosa
# Processing Record 1 of Set 8 | acapulco
# Processing Record 2 of Set 8 | tibu
# Processing Record 3 of Set 8 | vila
# Processing Record 4 of Set 8 | caravelas
# Processing Record 5 of Set 8 | ossora
# Processing Record 6 of Set 8 | berlevag
# Processing Record 7 of Set 8 | keuruu
# Processing Record 8 of Set 8 | bilibino
# Processing Record 9 of Set 8 | contai
# Processing Record 10 of Set 8 | rovaniemi
# Processing Record 11 of Set 8 | salalah
# Processing Record 12 of Set 8 | puerto leguizamo
# Processing Record 13 of Set 8 | kahului
# Processing Record 14 of Set 8 | olafsvik
# Processing Record 15 of Set 8 | la macarena
# Processing Record 16 of Set 8 | pangnirtung
# Processing Record 17 of Set 8 | horki
# Processing Record 18 of Set 8 | belle glade
# Processing Record 19 of Set 8 | beloha
# Processing Record 20 of Set 8 | rafaela
# Processing Record 21 of Set 8 | pilar
# Processing Record 22 of Set 8 | maniitsoq
# Processing Record 23 of Set 8 | hammerfest
# Processing Record 24 of Set 8 | ponta delgada
# Processing Record 25 of Set 8 | limbang
# Processing Record 26 of Set 8 | nanyamba
# Processing Record 27 of Set 8 | namibe
# Processing Record 28 of Set 8 | stargard szczecinski
# Processing Record 29 of Set 8 | fukue
# Processing Record 30 of Set 8 | pirovskoye
# Processing Record 31 of Set 8 | awjilah
# Processing Record 32 of Set 8 | parli
# Processing Record 33 of Set 8 | urucui
# Processing Record 34 of Set 8 | yanam
# Processing Record 35 of Set 8 | praya
# Processing Record 36 of Set 8 | manica
# Processing Record 37 of Set 8 | khash
# Processing Record 38 of Set 8 | prince rupert
# Processing Record 39 of Set 8 | trairi
# Processing Record 40 of Set 8 | guerrero negro
# Processing Record 41 of Set 8 | homer
# Processing Record 42 of Set 8 | sitka
# Processing Record 43 of Set 8 | yar-sale
# Processing Record 44 of Set 8 | joigny
# Processing Record 45 of Set 8 | port-cartier
# Processing Record 46 of Set 8 | vangaindrano
# Processing Record 47 of Set 8 | rocha
# Processing Record 48 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 49 of Set 8 | ganzhou
# Processing Record 50 of Set 8 | vanderhoof
# Processing Record 1 of Set 9 | noumea
# Processing Record 2 of Set 9 | meadow lake
# Processing Record 3 of Set 9 | minab
# Processing Record 4 of Set 9 | bayji
# Processing Record 5 of Set 9 | lofthus
# Processing Record 6 of Set 9 | zhangjiakou
# Processing Record 7 of Set 9 | nouakchott
# Processing Record 8 of Set 9 | victoria point
# Processing Record 9 of Set 9 | cartagena
# Processing Record 10 of Set 9 | healdsburg
# Processing Record 11 of Set 9 | oktyabrskoye
# Processing Record 12 of Set 9 | nanga eboko
# Processing Record 13 of Set 9 | onega
# Processing Record 14 of Set 9 | port keats
# Processing Record 15 of Set 9 | zharkovskiy
# Processing Record 16 of Set 9 | koumac
# Processing Record 17 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 18 of Set 9 | nikki
# Processing Record 19 of Set 9 | tlahualilo
# City not found. Skipping...
# Processing Record 20 of Set 9 | cururupu
# Processing Record 21 of Set 9 | namwala
# Processing Record 22 of Set 9 | yumen
# Processing Record 23 of Set 9 | garoua
# Processing Record 24 of Set 9 | caborca
# Processing Record 25 of Set 9 | rawah
# Processing Record 26 of Set 9 | te anau
# Processing Record 27 of Set 9 | bambanglipuro
# Processing Record 28 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 29 of Set 9 | whitehorse
# Processing Record 30 of Set 9 | balestrand
# Processing Record 31 of Set 9 | oksbol
# Processing Record 32 of Set 9 | castelfiorentino
# Processing Record 33 of Set 9 | irkutsk
# Processing Record 34 of Set 9 | riyadh
# Processing Record 35 of Set 9 | north bend
# Processing Record 36 of Set 9 | kargasok
# Processing Record 37 of Set 9 | campos
# Processing Record 38 of Set 9 | cleveland
# Processing Record 39 of Set 9 | taoudenni
# Processing Record 40 of Set 9 | galesong
# Processing Record 41 of Set 9 | leningradskiy
# Processing Record 42 of Set 9 | north platte
# Processing Record 43 of Set 9 | pocao de pedras
# Processing Record 44 of Set 9 | potosi
# Processing Record 45 of Set 9 | lata
# Processing Record 46 of Set 9 | alappuzha
# Processing Record 47 of Set 9 | estacion coahuila
# Processing Record 48 of Set 9 | dwarka
# Processing Record 49 of Set 9 | xuddur
# Processing Record 50 of Set 9 | novoilinsk
# Processing Record 1 of Set 10 | winton
# Processing Record 2 of Set 10 | bengkulu
# Processing Record 3 of Set 10 | alice springs
# Processing Record 4 of Set 10 | visby
# Processing Record 5 of Set 10 | ksenyevka
# City not found. Skipping...
# Processing Record 6 of Set 10 | zahesi
# Processing Record 7 of Set 10 | genhe
# Processing Record 8 of Set 10 | longyearbyen
# Processing Record 9 of Set 10 | lima
# Processing Record 10 of Set 10 | narsaq
# Processing Record 11 of Set 10 | shirokiy
# Processing Record 12 of Set 10 | los llanos de aridane
# Processing Record 13 of Set 10 | arkhara
# Processing Record 14 of Set 10 | oleksandrivka
# Processing Record 15 of Set 10 | manzil salim
# Processing Record 16 of Set 10 | svetlogorsk
# Processing Record 17 of Set 10 | moron
# Processing Record 18 of Set 10 | uglegorsk
# Processing Record 19 of Set 10 | ayagoz
# Processing Record 20 of Set 10 | hay river
# Processing Record 21 of Set 10 | padang
# Processing Record 22 of Set 10 | hualmay
# Processing Record 23 of Set 10 | coihaique
# Processing Record 24 of Set 10 | thongwa
# Processing Record 25 of Set 10 | san cristobal
# Processing Record 26 of Set 10 | yambio
# Processing Record 27 of Set 10 | kulhudhuffushi
# Processing Record 28 of Set 10 | bandarbeyla
# Processing Record 29 of Set 10 | anito
# Processing Record 30 of Set 10 | igboho
# Processing Record 31 of Set 10 | izhma
# Processing Record 32 of Set 10 | chapais
# Processing Record 33 of Set 10 | potiskum
# Processing Record 34 of Set 10 | aguas formosas
# Processing Record 35 of Set 10 | chama
# Processing Record 36 of Set 10 | garh maharaja
# Processing Record 37 of Set 10 | abu dhabi
# Processing Record 38 of Set 10 | diamantino
# Processing Record 39 of Set 10 | dimitrovgrad
# Processing Record 40 of Set 10 | phrai bung
# City not found. Skipping...
# Processing Record 41 of Set 10 | cherskiy
# Processing Record 42 of Set 10 | roma
# Processing Record 43 of Set 10 | mackenzie
# Processing Record 44 of Set 10 | marsh harbour
# Processing Record 45 of Set 10 | quesnel
# Processing Record 46 of Set 10 | kemijarvi
# Processing Record 47 of Set 10 | chepareria
# Processing Record 48 of Set 10 | trinidad
# Processing Record 49 of Set 10 | coetupo
# City not found. Skipping...
# Processing Record 50 of Set 10 | sibenik
# Processing Record 1 of Set 11 | natal
# Processing Record 2 of Set 11 | thompson
# Processing Record 3 of Set 11 | sao joao da barra
# Processing Record 4 of Set 11 | rapid valley
# Processing Record 5 of Set 11 | barra
# Processing Record 6 of Set 11 | burica
# City not found. Skipping...
# Processing Record 7 of Set 11 | storforshei
# Processing Record 8 of Set 11 | tilichiki
# Processing Record 9 of Set 11 | elko
# Processing Record 10 of Set 11 | dumbraveni
# Processing Record 11 of Set 11 | grand baie
# Processing Record 12 of Set 11 | bonoua
# Processing Record 13 of Set 11 | brae
# Processing Record 14 of Set 11 | kiunga
# Processing Record 15 of Set 11 | erzin
# Processing Record 16 of Set 11 | kysyl-syr
# Processing Record 17 of Set 11 | mosquera
# Processing Record 18 of Set 11 | shahr-e kord
# Processing Record 19 of Set 11 | codajas
# Processing Record 20 of Set 11 | kismayo
# Processing Record 21 of Set 11 | tecoanapa
# Processing Record 22 of Set 11 | pyinmana
# Processing Record 23 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 11 | half moon bay
# Processing Record 25 of Set 11 | pemangkat
# Processing Record 26 of Set 11 | enumclaw
# Processing Record 27 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 11 | axim
# Processing Record 29 of Set 11 | bathsheba
# Processing Record 30 of Set 11 | menzelinsk
# Processing Record 31 of Set 11 | sal rei
# Processing Record 32 of Set 11 | salvador
# Processing Record 33 of Set 11 | sinaia
# Processing Record 34 of Set 11 | sola
# Processing Record 35 of Set 11 | laguna
# Processing Record 36 of Set 11 | ciulnita
# Processing Record 37 of Set 11 | makarska
# Processing Record 38 of Set 11 | waipawa
# Processing Record 39 of Set 11 | gayeri
# Processing Record 40 of Set 11 | batagay
# Processing Record 41 of Set 11 | bay city
# Processing Record 42 of Set 11 | ihosy
# Processing Record 43 of Set 11 | lebowakgomo
# Processing Record 44 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 46 of Set 11 | nukus
# Processing Record 47 of Set 11 | kaeo
# Processing Record 48 of Set 11 | tome-acu
# City not found. Skipping...
# Processing Record 49 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 50 of Set 11 | sistranda
# Processing Record 1 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 12 | tual
# Processing Record 3 of Set 12 | kajaani
# Processing Record 4 of Set 12 | san quintin
# Processing Record 5 of Set 12 | baculin
# Processing Record 6 of Set 12 | hereclean
# Processing Record 7 of Set 12 | khani
# Processing Record 8 of Set 12 | muros
# Processing Record 9 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 10 of Set 12 | belmonte
# Processing Record 11 of Set 12 | katobu
# Processing Record 12 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 12 | yuxia
# Processing Record 14 of Set 12 | zhangye
# Processing Record 15 of Set 12 | lodwar
# Processing Record 16 of Set 12 | amarillo
# Processing Record 17 of Set 12 | palmer
# Processing Record 18 of Set 12 | lumut
# Processing Record 19 of Set 12 | orotukan
# Processing Record 20 of Set 12 | angoche
# Processing Record 21 of Set 12 | kirakira
# Processing Record 22 of Set 12 | flinders
# Processing Record 23 of Set 12 | airai
# Processing Record 24 of Set 12 | micheweni
# Processing Record 25 of Set 12 | lethem
# Processing Record 26 of Set 12 | aksarka
# Processing Record 27 of Set 12 | rodrigues alves
# Processing Record 28 of Set 12 | ornskoldsvik
# Processing Record 29 of Set 12 | rio grande
# Processing Record 30 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 31 of Set 12 | rabak
# Processing Record 32 of Set 12 | kumluca
# Processing Record 33 of Set 12 | muroto
# Processing Record 34 of Set 12 | tabulbah
# City not found. Skipping...
# Processing Record 35 of Set 12 | yinchuan
# Processing Record 36 of Set 12 | vestmanna
# Processing Record 37 of Set 12 | marzuq
# Processing Record 38 of Set 12 | grants
# Processing Record 39 of Set 12 | saint-joseph
# Processing Record 40 of Set 12 | teguldet
# Processing Record 41 of Set 12 | severo-zadonsk
# Processing Record 42 of Set 12 | sakaiminato
# Processing Record 43 of Set 12 | kesennuma
# City not found. Skipping...
# Processing Record 44 of Set 12 | hibbing
# Processing Record 45 of Set 12 | kota belud
# Processing Record 46 of Set 12 | lensk
# Processing Record 47 of Set 12 | kununurra
# Processing Record 48 of Set 12 | bastia
# Processing Record 49 of Set 12 | basco
# Processing Record 50 of Set 12 | saint-pierre
# Processing Record 1 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 13 | sao joao do paraiso
# Processing Record 3 of Set 13 | margate
# Processing Record 4 of Set 13 | santa maria
# Processing Record 5 of Set 13 | sept-iles
# Processing Record 6 of Set 13 | naliya
# Processing Record 7 of Set 13 | havoysund
# Processing Record 8 of Set 13 | walvis bay
# Processing Record 9 of Set 13 | sinnamary
# Processing Record 10 of Set 13 | dingle
# Processing Record 11 of Set 13 | tessalit
# Processing Record 12 of Set 13 | nunoa
# Processing Record 13 of Set 13 | korla
# Processing Record 14 of Set 13 | ballina
# Processing Record 15 of Set 13 | concordia
# Processing Record 16 of Set 13 | berezovka
# Processing Record 17 of Set 13 | westport
# Processing Record 18 of Set 13 | batemans bay
# Processing Record 19 of Set 13 | ketchikan
# Processing Record 20 of Set 13 | puerto el triunfo
# Processing Record 21 of Set 13 | cabo san lucas
# Processing Record 22 of Set 13 | bosaso
# Processing Record 23 of Set 13 | calama
# Processing Record 24 of Set 13 | geraldton
# Processing Record 25 of Set 13 | vostok
# Processing Record 26 of Set 13 | vanavara
# Processing Record 27 of Set 13 | sao gabriel da cachoeira
# Processing Record 28 of Set 13 | gornozavodsk
# Processing Record 29 of Set 13 | santiago de cao
# Processing Record 30 of Set 13 | naron
# Processing Record 31 of Set 13 | iwanai
# Processing Record 32 of Set 13 | yukhnov
# Processing Record 33 of Set 13 | rognan
# Processing Record 34 of Set 13 | gazojak
# Processing Record 35 of Set 13 | port shepstone
# Processing Record 36 of Set 13 | aktau
# Processing Record 37 of Set 13 | katsuura
# Processing Record 38 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 39 of Set 13 | hopkinsville
# Processing Record 40 of Set 13 | yudong
# Processing Record 41 of Set 13 | ulaangom
# Processing Record 42 of Set 13 | okhotsk
# Processing Record 43 of Set 13 | biryusinsk
# Processing Record 44 of Set 13 | abeche
# Processing Record 45 of Set 13 | pacific grove
# Processing Record 46 of Set 13 | belaya gora
# Processing Record 47 of Set 13 | montepuez
# Processing Record 48 of Set 13 | chara
# Processing Record 49 of Set 13 | namatanai
# Processing Record 50 of Set 13 | shetpe
# Processing Record 1 of Set 14 | bichura
# Processing Record 2 of Set 14 | ainazi
# Processing Record 3 of Set 14 | tarbert
# Processing Record 4 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 5 of Set 14 | niksic
# Processing Record 6 of Set 14 | arlit
# Processing Record 7 of Set 14 | tunyogmatolcs
# Processing Record 8 of Set 14 | kautokeino
# Processing Record 9 of Set 14 | birao
# Processing Record 10 of Set 14 | yermakovskoye
# Processing Record 11 of Set 14 | akdepe
# Processing Record 12 of Set 14 | shajapur
# Processing Record 13 of Set 14 | zavodoukovsk
# Processing Record 14 of Set 14 | matara
# Processing Record 15 of Set 14 | new braunfels
# Processing Record 16 of Set 14 | itoman
# Processing Record 17 of Set 14 | poum
# Processing Record 18 of Set 14 | halifax
# Processing Record 19 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 20 of Set 14 | hede
# Processing Record 21 of Set 14 | traiguen
# Processing Record 22 of Set 14 | petrovsk-zabaykalskiy
# Processing Record 23 of Set 14 | zhigansk
# Processing Record 24 of Set 14 | zaria
# Processing Record 25 of Set 14 | den helder
# Processing Record 26 of Set 14 | yakeshi
# Processing Record 27 of Set 14 | krasnoselkup
# Processing Record 28 of Set 14 | la ronge
# Processing Record 29 of Set 14 | hoi an
# Processing Record 30 of Set 14 | opuwo
# Processing Record 31 of Set 14 | bagru
# Processing Record 32 of Set 14 | kalmunai
# Processing Record 33 of Set 14 | tarpa
# Processing Record 34 of Set 14 | fonte boa
# Processing Record 35 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 14 | sorland
# Processing Record 37 of Set 14 | poronaysk
# Processing Record 38 of Set 14 | kotka
# Processing Record 39 of Set 14 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 40 of Set 14 | abalak
# Processing Record 41 of Set 14 | gat
# Processing Record 42 of Set 14 | rawson
# Processing Record 43 of Set 14 | haapiti
# Processing Record 44 of Set 14 | ternate
# Processing Record 45 of Set 14 | inhambane
# Processing Record 46 of Set 14 | kangaatsiaq
# Processing Record 47 of Set 14 | pangkalanbuun
# Processing Record 48 of Set 14 | pizarro
# Processing Record 49 of Set 14 | lorengau
# Processing Record 50 of Set 14 | vidim
# Processing Record 1 of Set 15 | banes
# Processing Record 2 of Set 15 | ambilobe
# Processing Record 3 of Set 15 | banda aceh
# Processing Record 4 of Set 15 | arcata
# Processing Record 5 of Set 15 | novaya ladoga
# Processing Record 6 of Set 15 | kolaras
# Processing Record 7 of Set 15 | skibbereen
# Processing Record 8 of Set 15 | methoni
# Processing Record 9 of Set 15 | mecca
# Processing Record 10 of Set 15 | mpanda
# Processing Record 11 of Set 15 | casa nova
# Processing Record 12 of Set 15 | cattolica
# Processing Record 13 of Set 15 | emmett
# Processing Record 14 of Set 15 | vila franca do campo
# Processing Record 15 of Set 15 | evensk
# Processing Record 16 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 15 | hare bay
# Processing Record 18 of Set 15 | dawei
# Processing Record 19 of Set 15 | huai thalaeng
# Processing Record 20 of Set 15 | sambava
# Processing Record 21 of Set 15 | murmashi
# Processing Record 22 of Set 15 | saint-francois
# Processing Record 23 of Set 15 | bara
# Processing Record 24 of Set 15 | ewo
# Processing Record 25 of Set 15 | maryville
# Processing Record 26 of Set 15 | dalvik
# Processing Record 27 of Set 15 | isiro
# Processing Record 28 of Set 15 | pijijiapan
# Processing Record 29 of Set 15 | port blair
# Processing Record 30 of Set 15 | codrington
# Processing Record 31 of Set 15 | gimli
# Processing Record 32 of Set 15 | sacramento
# Processing Record 33 of Set 15 | kenai
# Processing Record 34 of Set 15 | kungurtug
# Processing Record 35 of Set 15 | biak
# Processing Record 36 of Set 15 | tromso
# Processing Record 37 of Set 15 | abu zabad
# Processing Record 38 of Set 15 | arani
# Processing Record 39 of Set 15 | mitsamiouli
# Processing Record 40 of Set 15 | alta floresta
# Processing Record 41 of Set 15 | jiuquan
# Processing Record 42 of Set 15 | calatayud
# Processing Record 43 of Set 15 | havre-saint-pierre
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

#reorder dataframe
new_column_order = ["City", "Country","Lat", "Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df.head(15)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0       Clyde River      CA  70.4692  -68.5914     43.03        70
# 1     Berdigestyakh      RU  62.0989  126.6992     54.48        94
# 2             Tiksi      RU  71.6872  128.8694     38.75        92
# 3   Arraial Do Cabo      BR -22.9661  -42.0278     84.16        51
# 4         Ostrovnoy      RU  68.0531   39.5131     62.38        63
# 5        Bredasdorp      ZA -34.5322   20.0403     53.11        88
# 6             Chato      TZ  -2.6378   31.7669     72.75        45
# 7            Barrow      US  71.2906 -156.7887     46.42        87
# 8            Dikson      RU  73.5069   80.5464     37.08        88
# 9          Sungurlu      TR  40.1675   34.3739     75.38        45
# 10             Kabo      CF   7.6994   18.6290     80.49        71
# 11        Hithadhoo      MV  -0.6000   73.0833     82.85        76
# 12        Mogadishu      SO   2.0371   45.3438     76.60        81
# 13      Provideniya      RU  64.3833 -173.3000     52.02        82
# 14        Morondava      MG -20.2833   44.2833     73.62        79
#
#     Cloudiness  Wind Speed Current Description
# 0          100        9.22          light rain
# 1           60        8.34          light rain
# 2           82       15.39       broken clouds
# 3            0       13.80           clear sky
# 4           91        8.39     overcast clouds
# 5           50        4.63    scattered clouds
# 6            9        2.17           clear sky
# 7           20        4.61          few clouds
# 8          100        9.91          light rain
# 9            1        7.52           clear sky
# 10          43        0.38    scattered clouds
# 11         100        5.66     overcast clouds
# 12          37       20.49          light rain
# 13          94        3.71     overcast clouds
# 14           0       15.10           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
